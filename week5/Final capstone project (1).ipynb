# %% [markdown]
# ## Final Report | Capstone Project – The Battle of Neighborhoods
# ### To Find best fitted neighorhoods in Toronto ,Canada

# %% [markdown]
# ### Introduction

# %% [markdown]
# The purpose of this project is to exploring best neighborhood in toronto to match the same lifesytle when lived in new york.
# Even toronto is not very far from new york, there are still lots difference between two cities. So it's not a easy thing to find good neighborhhod then move to another city when they first come to new area. people want to keep their lifestyle , sush as close to art galleries, easy to accessing cafe shop, local resturants, hospital maybe....

# %% [markdown]
# For detail , this project is about :
#      I am now living in manhattan ,new york which the one of the most famous cities in the world and the the neigborhood name is Chelsea. I am very satisfied with current location. Two week ago , a new work offer from toronto sent to me with better benefits and opportunity . So i
# accept this offer and preapre move to toronto. I need to find which neighborhood is best fit for me.

# %% [markdown]
# ### Data Selection

# %% [markdown]
# Data link (Toronto): https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
# Data link (New york): https://cocl.us/new_york_dataset
#
# Note: We only use city of Tonronto data

# %% [markdown]
# We have to find current venues and explore neighborhoods both in new york and toronto. So we need to use Foursqaure location information.
# After finding the list of neighborhoods, we then connect to the Foursquare API to gather information about venues inside each and every neighborhood.
# For each neighborhood, we have chosen the radius to be 500 meter.then we find the top 10 most popular categories for each cluster in toronto.
#
# The information obtained per as follows:
#
# 1. Neighborhood
# 2. Neighborhood Latitude
# 3. Neighborhood Longitude
# 4. Venue
# 5. Name of the venue e.g. the name of a store or restaurant
# 6. Venue Latitude
# 7. Venue Longitude
# 8. Venue Category
#
# Map of toronto :(I only need foucs on downtown and midtown neighborhoods , because it's not too far to my work palce in downtown.)

# %% [markdown]
# ![toronto%20photo.PNG](attachment:toronto%20photo.PNG)

# %% [markdown]
# ### Methodolgy

# %% [markdown]
# K-mean Clustering approach:
# To comapre the two cities, i grouped segment of neighborhood into serveral clusters.Each cluster represent a group of similar neighborhhod. then we can oick a most closer neighborhhod in toronto to match with new york's.

# %% [markdown]
# This is cluster report of toronto.
# ![toronto_clusters.PNG](attachment:toronto_clusters.PNG)

# %% [markdown]
# ### Workflow

# %% [markdown]
# Using Foursqaure API to get the new york data then find the from top popular to 10th popular venue. When we found my current lifestyle in new york, then to use the clustering results from week 3 project compare to find which neigborhood is best fit for me.

# %% [markdown]
# ### Discussion

# %% [markdown]
# ![chelsea_info.PNG](attachment:chelsea_info.PNG)
# Above is the characteristics graph of chelsea which is i am current living.

# %% [markdown]
# As we see from clusters graph, i used 10 clusters to group all neighborhhods.  I only want to select from cluster1,3,4,7,8,9 as there are the right distance range between work and home place.Also, i want to mention ,becasue toronto is not a top level cites in world(only New york and London ). So it's hardly to find art galleries. For this resaon, i have to remove the art gallery. Then , from general level, for my understanding, poeple living Cheslea ,new york like muti-culture restaurant,local store and local market(not franchise store).
#
# So based on above info,i will prefer to choose Davisville,The Danforth West / Riverdale,Berczy Park or St. James Town / Cabbagetown, becasue it's not too close or too far from my work place in downtown and lifestyle looks same as in new york.

# %% [markdown]
# ### Further reseach:
# Maybe, i have to find the crime information for each neighborhhod, revenue info and apartment rental info for robust results.
